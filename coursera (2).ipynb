# %% [markdown]
# This is the notbook for Coursera Capstone

# %%
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 
import requests 
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium 

print('Libraries imported.')
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.25.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Libraries imported.

# %%
table = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

# %%
df=table[0]

# %%
dfd1=df[df.Borough!="Not assigned"]

# %%
df = dfd1.reset_index(drop=True)

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## The dataframe above is the cleaned dataframe of the WIKI web
# #### I clean up the dataframe by cleaning out the Borough that is "not assigned"

# %%
import geocoder # import geocoder
from geopy.geocoders import Nominatim

# %% [markdown]
# #### The Geocader is not worked for my python, so I download the csv.

# %%
geo=pd.read_csv("http://cocl.us/Geospatial_data")
geo
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %%
k=df["Postal Code"]
pc=list(k.values)
lat=[]
lon=[]

# %%
for n in pc:
    lat.append(float(geo[geo["Postal Code"]==n]["Latitude"].values))
    lon.append(float(geo[geo["Postal Code"]==n]["Longitude"].values))

# %%
df["Latitude"]=lat
df["Longitude"]=lon

# %%
kclusters = 5
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df[["Latitude","Longitude"]])

# %%
df.insert(0, 'Cluster Labels', kmeans.labels_)
df
# Out:
#      Cluster Labels Postal Code           Borough  \
# 0                 4         M3A        North York
# 1                 4         M4A        North York
# 2                 2         M5A  Downtown Toronto
# 3                 0         M6A        North York
# 4                 2         M7A  Downtown Toronto
# 5                 1         M9A         Etobicoke
# 6                 3         M1B       Scarborough
# 7                 4         M3B        North York
# 8                 4         M4B         East York
# 9                 2         M5B  Downtown Toronto
# 10                0         M6B        North York
# 11                1         M9B         Etobicoke
# 12                3         M1C       Scarborough
# 13                4         M3C        North York
# 14                4         M4C         East York
# 15                2         M5C  Downtown Toronto
# 16                2         M6C              York
# 17                1         M9C         Etobicoke
# ...

# %% [markdown]
# #### So above here we get the final version of our dataframe with the updated latitude and longitude

# %%
# create map
map_clusters = folium.Map(location=[43.716316,-79.239476], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df['Latitude'], df['Longitude'], df['Neighborhood'], df['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### so by clustering, we have 5 cluster groups of the districs by the latitude and longtitude of different postal zones.
